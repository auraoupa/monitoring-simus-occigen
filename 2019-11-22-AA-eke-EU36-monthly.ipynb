# %%
from dask_jobqueue import SLURMCluster 
from dask.distributed import Client 
  
cluster = SLURMCluster(cores=28,name='make_profiles',walltime='00:30:00',job_extra=['--constraint=HSW24','--exclusive','--nodes=1'],memory='120GB',interface='ib0') 
cluster.scale(196)
cluster
# Out:
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/bokeh/core.py:74: UserWarning:
# Failed to start diagnostics server on port 8787. [Errno 13] Permission denied
#   warnings.warn("\n" + msg)
# VBox(children=(HTML(value='<h2>SLURMCluster</h2>'), HBox(children=(HTML(value='\n<div>\n  <style scoped>\n    …

# %%
from dask.distributed import Client
client = Client(cluster)
client
# Out:
# <Client: scheduler='tcp://172.30.100.2:42137' processes=0 cores=0>

# %%
# !squeue -u albert7a
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            8154931     hsw24 make_pro albert7a PD       0:00      1 (None)
#            8154932     hsw24 make_pro albert7a PD       0:00      1 (None)
#            8154933     hsw24 make_pro albert7a PD       0:00      1 (None)
#            8154934     hsw24 make_pro albert7a PD       0:00      1 (None)
#            8154935     hsw24 make_pro albert7a PD       0:00      1 (None)
#            8154936     hsw24 make_pro albert7a PD       0:00      1 (None)
#            8154937     hsw24 make_pro albert7a PD       0:00      1 (None)

# %%
import time
nb_workers = 0
while True:
    nb_workers = len(client.scheduler_info()["workers"])
    if nb_workers >= 2:
        break
    time.sleep(1)
print(nb_workers)
# Out:
# 24

# %%
import sys
import numpy as np
import numpy.ma as ma
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.feature as cfeature
import cmocean
import glob

# %matplotlib inline
# Out:
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/merge.py:16: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   PANDAS_TYPES = (pd.Series, pd.DataFrame, pd.Panel)

# %%
config='EU36'
case='MPC001'
freq='1d'
year='2012'

datadir='/scratch/cnt0024/hmg2840/colombo/'+str(config)+'/'+str(config)+'-'+str(case)+'-S/'+str(freq)+'/'+str(year)+'/'
#!ls $datadir
gridfile='/scratch/cnt0024/hmg2840/colombo/EU36/EU36-I/coordinates_EU36.nc'
maskfile='/scratch/cnt0024/hmg2840/colombo/EU36/EU36-I/EU36.L75_mesh_mask.nc'

# %%
dsgrid=xr.open_dataset(gridfile)
dsmask=xr.open_dataset(maskfile)

# %%
def compute_EKE(u2,v2,u2mean,v2mean):
    ua=0.5*((-1*u2+u2mean)+(-1*u2.shift(x=1)+u2mean.shift(x=1)))
    va=0.5*((-1*v2+v2mean)+(-1*v2.shift(y=1)+v2mean.shift(y=1)))
    uat=ua.rename({'depthu':'deptht'})
    vat=va.rename({'depthv':'deptht'})
    eke=0.5*(uat+vat)
    return eke

# %%
month_name={1:'January',2:'February',3:'March',4:'April',5:'May',6:'June',7:'July',8:'August',9:'September',10:'October',11:'November',12:'December'}
def plot_one_month(var,vmin,vmax,cmap,title,figfile,month,year):
    fig, ax = plt.subplots(1,1,figsize=(10,15))
    var.plot(cmap=cmap,ax=ax,vmin=vmin,vmax=vmax,add_labels=True)
    ax.set_title(month_name[month])
    fig.suptitle('Monthly mean of '+str(title))
    plt.savefig('Plots/EU36/Maps/'+config+'-'+case+'y'+str(year)+'m'+str(month)+'_'+figfile+'.png')

# %%
filesU=sorted(glob.glob(datadir+'/'+str(config)+'-'+str(case)+'_y'+str(year)+'m??d??.'+str(freq)+'_gridU.nc'))
filesV=sorted(glob.glob(datadir+'/'+str(config)+'-'+str(case)+'_y'+str(year)+'m??d??.'+str(freq)+'_gridV.nc'))
dsU=xr.open_mfdataset(filesU, chunks={'x':700,'y':1000,'time_counter':10,'depthu':1})
dsV=xr.open_mfdataset(filesV, chunks={'x':700,'y':1000,'time_counter':10,'depthv':1})
u=dsU.vozocrtx
v=dsV.vomecrty
u2=u*u
v2=v*v
u2mean=u2.mean(dim='time_counter')
v2mean=v2.mean(dim='time_counter')
umonth=u.groupby('time_counter.month').mean('time_counter')
vmonth=v.groupby('time_counter.month').mean('time_counter')
umonth2=umonth*umonth
vmonth2=vmonth*vmonth
umonth2mean=umonth2.mean(dim='month')
vmonth2mean=vmonth2.mean(dim='month')
eke=compute_EKE(umonth2,vmonth2,umonth2mean,vmonth2mean)
for m in np.arange(1,13):
    print('Plotting for month '+str(m))
    plot_one_month(10000*eke[m-1,0],-2500,2500,'cmo.balance','Surface EKE y'+year,'eke_surf',m,year)
# Out:
# Plotting for month 1
# Plotting for month 2
# Plotting for month 3
# Plotting for month 4
# Plotting for month 5
# Plotting for month 6
# Plotting for month 7
# Plotting for month 8
# Plotting for month 9
# distributed.utils_perf - WARNING - full garbage collections took 18% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# Plotting for month 10
# distributed.utils_perf - WARNING - full garbage collections took 19% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# Plotting for month 11
# distributed.utils_perf - WARNING - full garbage collections took 20% CPU time recently (threshold: 10%)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-f5c1c1cb5a75> in <module>
#      18 for m in np.arange(1,13):
#      19     print('Plotting for month '+str(m))
# ---> 20     plot_one_month(10000*eke[m-1,0],-2500,2500,'cmo.balance','Surface EKE y'+year,'eke_surf',m,year)
#      21
#
# <ipython-input-9-555f5cf45754> in plot_one_month(var, vmin, vmax, cmap, title, figfile, month, year)
#       2 def plot_one_month(var,vmin,vmax,cmap,title,figfile,month,year):
#       3     fig, ax = plt.subplots(1,1,figsize=(10,15))
# ----> 4     var.plot(cmap=cmap,ax=ax,vmin=vmin,vmax=vmax,add_labels=True)
#       5     ax.set_title(month_name[month])
#       6     fig.suptitle('Monthly mean of '+str(title))
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/plot/plot.py in __call__(self, **kwargs)
#     421
#     422     def __call__(self, **kwargs):
# --> 423         return plot(self._da, **kwargs)
#     424
#     425     @functools.wraps(hist)
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/plot/plot.py in plot(darray, row, col, col_wrap, ax, hue, rtol, subplot_kws, **kwargs)
#     170     kwargs['ax'] = ax
#     171
# --> 172     return plotfunc(darray, **kwargs)
#     173
#     174
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/plot/plot.py in newplotfunc(darray, x, y, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_colorbar, add_labels, vmin, vmax, cmap, center, robust, extend, levels, infer_intervals, colors, subplot_kws, cbar_ax, cbar_kwargs, xscale, yscale, xticks, yticks, xlim, ylim, norm, **kwargs)
#     620
#     621         # Pass the data as a masked ndarray too
# --> 622         zval = darray.to_masked_array(copy=False)
#     623
#     624         # Replace pd.Intervals if contained in xval or yval.
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/dataarray.py in to_masked_array(self, copy)
#    1685             Masked where invalid values (nan or inf) occur.
#    1686         """
# -> 1687         isnull = pd.isnull(self.values)
#    1688         return np.ma.MaskedArray(data=self.values, mask=isnull, copy=copy)
#    1689
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/dataarray.py in values(self)
#     410     def values(self):
#     411         """The array's data as a numpy.ndarray"""
# --> 412         return self.variable.values
#     413
#     414     @values.setter
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/variable.py in values(self)
#     385     def values(self):
#     386         """The variable's data as a numpy.ndarray"""
# --> 387         return _as_array_or_item(self._data)
#     388
#     389     @values.setter
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/variable.py in _as_array_or_item(data)
#     206     TODO: remove this (replace with np.asarray) once these issues are fixed
#     207     """
# --> 208     data = np.asarray(data)
#     209     if data.ndim == 0:
#     210         if data.dtype.kind == 'M':
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/dask/array/core.py in __array__(self, dtype, **kwargs)
#     996
#     997     def __array__(self, dtype=None, **kwargs):
# --> 998         x = self.compute()
#     999         if dtype and x.dtype != dtype:
#    1000             x = x.astype(dtype)
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/dask/base.py in compute(self, **kwargs)
#     154         dask.base.compute
#     155         """
# --> 156         (result,) = compute(self, traverse=False, **kwargs)
#     157         return result
#     158
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/dask/base.py in compute(*args, **kwargs)
#     396     keys = [x.__dask_keys__() for x in collections]
#     397     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 398     results = schedule(dsk, keys, **kwargs)
#     399     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     400
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2566                     should_rejoin = False
#    2567             try:
# -> 2568                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2569             finally:
#    2570                 for f in futures.values():
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/client.py in gather(self, futures, errors, maxsize, direct, asynchronous)
#    1820                 direct=direct,
#    1821                 local_worker=local_worker,
# -> 1822                 asynchronous=asynchronous,
#    1823             )
#    1824
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/client.py in sync(self, func, *args, **kwargs)
#     751             return future
#     752         else:
# --> 753             return sync(self.loop, func, *args, **kwargs)
#     754
#     755     def __repr__(self):
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/utils.py in sync(loop, func, *args, **kwargs)
#     329             e.wait(10)
#     330     if error[0]:
# --> 331         six.reraise(*error[0])
#     332     else:
#     333         return result[0]
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/utils.py in f()
#     314             if timeout is not None:
#     315                 future = gen.with_timeout(timedelta(seconds=timeout), future)
# --> 316             result[0] = yield future
#     317         except Exception as exc:
#     318             error[0] = sys.exc_info()
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     733
#     734                     try:
# --> 735                         value = future.result()
#     736                     except Exception:
#     737                         exc_info = sys.exc_info()
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py in run(self)
#     740                     if exc_info is not None:
#     741                         try:
# --> 742                             yielded = self.gen.throw(*exc_info)  # type: ignore
#     743                         finally:
#     744                             # Break up a reference to itself
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/client.py in _gather(self, futures, errors, direct, local_worker)
#    1651                             six.reraise(CancelledError, CancelledError(key), None)
#    1652                         else:
# -> 1653                             six.reraise(type(exception), exception, traceback)
#    1654                     if errors == "skip":
#    1655                         bad_keys.add(key)
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     690                 value = tp()
#     691             if value.__traceback__ is not tb:
# --> 692                 raise value.with_traceback(tb)
#     693             raise value
#     694         finally:
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/dask/array/core.py in getter()
#      80         c = a[b]
#      81         if asarray:
# ---> 82             c = np.asarray(c)
#      83     finally:
#      84         if lock:
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray()
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/indexing.py in __array__()
#     602
#     603     def __array__(self, dtype=None):
# --> 604         return np.asarray(self.array, dtype=dtype)
#     605
#     606     def __getitem__(self, key):
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray()
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/indexing.py in __array__()
#     508     def __array__(self, dtype=None):
#     509         array = as_indexable(self.array)
# --> 510         return np.asarray(array[self.key], dtype=None)
#     511
#     512     def transpose(self, order):
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray()
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/coding/variables.py in __array__()
#      66
#      67     def __array__(self, dtype=None):
# ---> 68         return self.func(self.array)
#      69
#      70     def __repr__(self):
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/coding/variables.py in _apply_mask()
#     133 ) -> np.ndarray:
#     134     """Mask all matching values in a NumPy arrays."""
# --> 135     data = np.asarray(data, dtype=dtype)
#     136     condition = False
#     137     for fv in encoded_fill_values:
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray()
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/indexing.py in __array__()
#     508     def __array__(self, dtype=None):
#     509         array = as_indexable(self.array)
# --> 510         return np.asarray(array[self.key], dtype=None)
#     511
#     512     def transpose(self, order):
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in __getitem__()
#      62         return indexing.explicit_indexing_adapter(
#      63             key, self.shape, indexing.IndexingSupport.OUTER,
# ---> 64             self._getitem)
#      65
#      66     def _getitem(self, key):
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/indexing.py in explicit_indexing_adapter()
#     776     """
#     777     raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 778     result = raw_indexing_method(raw_key.tuple)
#     779     if numpy_indices.tuple:
#     780         # index the loaded np.ndarray
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in _getitem()
#      72         try:
#      73             with self.datastore.lock:
# ---> 74                 original_array = self.get_array(needs_lock=False)
#      75                 array = getitem(original_array, key)
#      76         except IndexError:
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in get_array()
#      54
#      55     def get_array(self, needs_lock=True):
# ---> 56         ds = self.datastore._manager.acquire(needs_lock).value
#      57         return ds.variables[self.variable_name]
#      58
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/backends/file_manager.py in acquire()
#     171                     kwargs = kwargs.copy()
#     172                     kwargs['mode'] = self._mode
# --> 173                 file = self._opener(*self._args, **kwargs)
#     174                 if self._mode == 'w':
#     175                     # ensure file doesn't get overriden when opened again
#
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in _open_netcdf4_group()
#     242     import netCDF4 as nc4
#     243
# --> 244     ds = nc4.Dataset(filename, mode=mode, **kwargs)
#     245
#     246     with close_on_error(ds):
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# OSError: [Errno -101] NetCDF: HDF error: b'/scratch/cnt0024/hmg2840/colombo/EU36/EU36-MPC001-S/1d/2012/EU36-MPC001_y2012m02d29.1d_gridV.nc'
