# %%
from dask_jobqueue import SLURMCluster 
from dask.distributed import Client 
  
cluster = SLURMCluster(cores=28,name='make_profiles',walltime='00:30:00',job_extra=['--constraint=HSW24','--exclusive','--nodes=1'],memory='120GB',interface='ib0') 
cluster.scale(168)
cluster
# Out:
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/bokeh/core.py:74: UserWarning:
# Failed to start diagnostics server on port 8787. [Errno 13] Permission denied
#   warnings.warn("\n" + msg)
# VBox(children=(HTML(value='<h2>SLURMCluster</h2>'), HBox(children=(HTML(value='\n<div>\n  <style scoped>\n    …

# %%
from dask.distributed import Client
client = Client(cluster)
client
# Out:
# <Client: scheduler='tcp://172.30.100.3:34376' processes=0 cores=0>

# %%
# !squeue -u albert7a
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            7611739     hsw24 make_pro albert7a  R       0:00      1 n2253
#            7611740     hsw24 make_pro albert7a  R       0:00      1 n3003
#            7611741     hsw24 make_pro albert7a  R       0:00      1 n3010
#            7611742     hsw24 make_pro albert7a  R       0:00      1 n2566
#            7611743     hsw24 make_pro albert7a  R       0:00      1 n2567
#            7611744     hsw24 make_pro albert7a  R       0:00      1 n2568

# %%
import time
nb_workers = 0
while True:
    nb_workers = len(client.scheduler_info()["workers"])
    if nb_workers >= 2:
        break
    time.sleep(1)
print(nb_workers)
# Out:
# 136

# %%
# !squeue -u albert7a
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#            7611739     hsw24 make_pro albert7a  R       0:12      1 n2253
#            7611740     hsw24 make_pro albert7a  R       0:12      1 n3003
#            7611741     hsw24 make_pro albert7a  R       0:12      1 n3010
#            7611742     hsw24 make_pro albert7a  R       0:12      1 n2566
#            7611743     hsw24 make_pro albert7a  R       0:12      1 n2567
#            7611744     hsw24 make_pro albert7a  R       0:12      1 n2568

# %%
import sys
import numpy as np
import numpy.ma as ma
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.feature as cfeature
import cmocean
import glob

# %matplotlib inline
# Out:
# /scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/xarray/core/merge.py:16: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   PANDAS_TYPES = (pd.Series, pd.DataFrame, pd.Panel)

# %%
config='NATL60'
case='CJM165'
freq='1d'
#year='2010' #depends on the month

datadir='/store/molines/'+str(config)+'/'+str(config)+'-'+str(case)+'-S/'+str(freq)+'/'
#!ls $datadir
gridfile='/store/molines/NATL60/NATL60-I/NATL60_coordinates_v4.nc'
maskfile='/store/molines/NATL60/NATL60-I/NATL60_v4.1_cdf_byte_mask.nc'

# %%
dsgrid=xr.open_dataset(gridfile)
dsmask=xr.open_dataset(maskfile)

# %%
def compute_EKE(u,v,u2mean,v2mean):
    ua=0.5*((u2mean-u*u)+(u2mean.shift(x=-1)-u.shift(x=-1)*u.shift(x=-1)))
    va=0.5*((v2mean-v*v)+(v2mean.shift(y=-1)-v.shift(y=-1)*v.shift(y=-1)))
    uat=ua.rename({'depthu':'deptht'})
    vat=va.rename({'depthv':'deptht'})
    eke=0.5*(uat+vat)
    return eke

# %%
month_name={1:'January',2:'February',3:'March',4:'April',5:'May',6:'June',7:'July',8:'August',9:'September',10:'October',11:'November',12:'December'}
def plot_monthly(var,mask,vmin,vmax,cmap,title,figfile):
    fig, axes = plt.subplots(3,4,figsize=(30,20))
    axes = axes.ravel()
    for m in np.arange(1,13):
        if m < 10:
            month='0'+str(m)
        else:
            month=str(m)
        if m in [1,3,5,7,8,10,12]:
            dayf='31'
        elif m == 2:
            dayf='28'
        else:
            dayf='30'
        if m < 10:
            year='2013'
        else:
            year='2012'
        ax=axes[m-1]
        var.sel(time_counter=slice(str(year)+'-'+month+'-01',str(year)+'-'+month+'-'+dayf)).mean(dim='time_counter').where(mask==1).plot(cmap=cmap,ax=ax,vmin=vmin,vmax=vmax,add_labels=True)
        ax.set_title(month_name[m])
    fig.suptitle('Monthly mean of '+str(title))
    plt.savefig(config+'-'+case+'y'+str(year)+'.1m_'+figfile+'.png')

# %%
month_name={1:'January',2:'February',3:'March',4:'April',5:'May',6:'June',7:'July',8:'August',9:'September',10:'October',11:'November',12:'December'}
def plot_one_month(var,mask,vmin,vmax,cmap,title,figfile,month,year,m):
    fig, ax = plt.subplots(1,1,figsize=(10,15))
    var.mean(dim='time_counter').where(mask==1).plot(cmap=cmap,ax=ax,vmin=vmin,vmax=vmax,add_labels=True)
    ax.set_title(month_name[m])
    fig.suptitle('Monthly mean of '+str(title))
    plt.savefig(config+'-'+case+'y'+str(year)+'m'+str(month)+'_'+figfile+'.png')

# %%
def plot_annual(var,mask,vmin,vmax,cmap,title,figfile):
    fig, ax = plt.subplots(1,1,figsize=(10,15))
    var.mean(dim='time_counter').where(mask==1).plot(cmap=cmap,ax=ax,vmin=vmin,vmax=vmax,add_labels=True)
    fig.suptitle('Annual mean of '+str(title))
    plt.savefig(config+'-'+case+'_y'+str(year)+'.1y_'+figfile+'.png')

# %%
m=1
if m < 10:
    month='0'+str(m)
else:
    month=str(m)
if m < 10:
    year='2013'
else:
    year='2012'

# %%
filesU=sorted(glob.glob(datadir+'/*/'+str(config)+'-'+str(case)+'_y'+str(year)+'m'+str(month)+'d??.'+str(freq)+'_gridU.nc'))

# %%
filesV=sorted(glob.glob(datadir+'/*/'+str(config)+'-'+str(case)+'_y'+str(year)+'m'+str(month)+'d??.'+str(freq)+'_gridV.nc'))

# %%
dsU=xr.open_mfdataset(filesU, chunks={'x':700,'y':1000,'time_counter':1,'depthu':1})

# %%
dsV=xr.open_mfdataset(filesV, chunks={'x':700,'y':1000,'time_counter':1,'depthv':1})

# %%
u=dsU.vozocrtx[:,:,424:3286,3858:5076]

# %%
v=dsV.vomecrty[:,:,424:3286,3858:5076]

# %%
u
# Out:
# <xarray.DataArray 'vozocrtx' (time_counter: 31, depthu: 300, y: 2862, x: 1218)>
# dask.array<shape=(31, 300, 2862, 1218), dtype=float32, chunksize=(1, 1, 576, 342)>
# Coordinates:
#   * depthu         (depthu) float32 0.48045477 1.5587916 ... 5974.8853 6025.346
#     nav_lat        (time_counter, y, x) float32 dask.array<shape=(31, 2862, 1218), chunksize=(1, 576, 342)>
#     nav_lon        (time_counter, y, x) float32 dask.array<shape=(31, 2862, 1218), chunksize=(1, 576, 342)>
#     time_centered  (time_counter) datetime64[ns] dask.array<shape=(31,), chunksize=(1,)>
#   * time_counter   (time_counter) datetime64[ns] 2013-01-01T12:00:00 ... 2013-01-31T12:00:00
# Dimensions without coordinates: y, x
# Attributes:
#     standard_name:       sea_water_x_velocity
#     long_name:           ocean current along i-axis
#     units:               m/s
#     online_operation:    average
#     interval_operation:  40 s
#     interval_write:      1 d
#     cell_methods:        time: mean (interval: 40 s)

# %%
fig, ax = plt.subplots(1,1,figsize=(10,15))
u[:,0].mean(dim='time_counter').where(mask[0]==1).plot(cmap='cmo.balance',ax=ax,vmin=-2,vmax=2,add_labels=True)

# %%
fig, ax = plt.subplots(1,1,figsize=(10,15))
v[:,0].mean(dim='time_counter').where(mask[0]==1).plot(cmap='cmo.balance',ax=ax,vmin=-2,vmax=2,add_labels=True)

# %%
mask=dsmask.tmask[0,:,424:3286,3858:5076]

# %%
fig, ax = plt.subplots(1,1,figsize=(10,15))
u2[:,0].mean(dim='time_counter').where(mask[0]==1).plot(cmap='cmo.amp',ax=ax,vmin=0,vmax=4,add_labels=True)

# %%
fig, ax = plt.subplots(1,1,figsize=(10,15))
v2[:,0].mean(dim='time_counter').where(mask[0]==1).plot(cmap='cmo.amp',ax=ax,vmin=0,vmax=4,add_labels=True)

# %%
u2[:,0]

# %%
u2mean
# Out:
# <xarray.DataArray 'vozocrtx' (depthu: 300, y: 2862, x: 1218)>
# dask.array<shape=(300, 2862, 1218), dtype=float32, chunksize=(1, 576, 342)>
# Coordinates:
#   * depthu   (depthu) float32 0.48045477 1.5587916 ... 5974.8853 6025.346
# Dimensions without coordinates: y, x

# %%
u2
# Out:
# <xarray.DataArray 'vozocrtx' (time_counter: 31, depthu: 300, y: 2862, x: 1218)>
# dask.array<shape=(31, 300, 2862, 1218), dtype=float32, chunksize=(1, 1, 576, 342)>
# Coordinates:
#   * depthu         (depthu) float32 0.48045477 1.5587916 ... 5974.8853 6025.346
#     nav_lat        (time_counter, y, x) float32 dask.array<shape=(31, 2862, 1218), chunksize=(1, 576, 342)>
#     nav_lon        (time_counter, y, x) float32 dask.array<shape=(31, 2862, 1218), chunksize=(1, 576, 342)>
#     time_centered  (time_counter) datetime64[ns] dask.array<shape=(31,), chunksize=(1,)>
#   * time_counter   (time_counter) datetime64[ns] 2013-01-01T12:00:00 ... 2013-01-31T12:00:00
# Dimensions without coordinates: y, x

# %%
diff=u2mean-u2

# %%
u2mean_br=xr.broadcast(u2mean,u)
diff_br=u2mean_br-u2
# Out:
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:51328 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:51330 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:51332 remote=tcp://172.30.100.3:34376>
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.8.127:39811'], ('transpose-22802e79086ac0bc276805454066dbe9', 222, 1, 1, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.8.128:35598'], ('transpose-22802e79086ac0bc276805454066dbe9', 145, 2, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.10.59:34373'], ('transpose-22802e79086ac0bc276805454066dbe9', 53, 3, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.10.59:44157'], ('transpose-22802e79086ac0bc276805454066dbe9', 280, 3, 1, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.10.59:41566'], ('transpose-22802e79086ac0bc276805454066dbe9', 165, 3, 2, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.10.59:44304'], ('transpose-22802e79086ac0bc276805454066dbe9', 31, 3, 2, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.22:38327'], ('transpose-22802e79086ac0bc276805454066dbe9', 285, 2, 2, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.10.59:45396'], ('transpose-22802e79086ac0bc276805454066dbe9', 3, 1, 0, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.6.22:38645'], ('transpose-22802e79086ac0bc276805454066dbe9', 251, 0, 1, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.8.127
 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.8.127:38561'], ('transpose-22802e79086ac0bc276805454066dbe9', 103, 0, 2, 0)
# NoneType: None
# distributed.scheduler - ERROR - Workers don't have promised key: ['tcp://172.30.8.127:39481'], ('transpose-22802e79086ac0bc276805454066dbe9', 104, 0, 2, 0)
# NoneType: None
# ...
#     yielded = self.gen.send(value)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/core.py", line 471, in handle_stream
#     handler(**merge(extra, msg))
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 2326, in handle_release_data
#     ws = self.workers[worker]
# KeyError: 'tcp://172.30.8.129:35635'
# distributed.utils - ERROR - Worker already exists tcp://172.30.10.59:41284
# Traceback (most recent call last):
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/utils.py", line 713, in log_errors
#     yield
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 1410, in add_worker
#     raise ValueError("Worker already exists %s" % address)
# ValueError: Worker already exists tcp://172.30.10.59:41284
# distributed.core - ERROR - Worker already exists tcp://172.30.10.59:41284
# Traceback (most recent call last):
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/core.py", line 412, in handle_comm
#     result = yield result
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 1410, in add_worker
#     raise ValueError("Worker already exists %s" % address)
# ValueError: Worker already exists tcp://172.30.10.59:41284
# distributed.utils - ERROR - Worker already exists tcp://172.30.10.59:44965
# Traceback (most recent call last):
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/utils.py", line 713, in log_errors
#     yield
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 1410, in add_worker
#     raise ValueError("Worker already exists %s" % address)
# ValueError: Worker already exists tcp://172.30.10.59:44965
# distributed.core - ERROR - Worker already exists tcp://172.30.10.59:44965
# Traceback (most recent call last):
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/core.py", line 412, in handle_comm
#     result = yield result
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 1410, in add_worker
#     raise ValueError("Worker already exists %s" % address)
# ValueError: Worker already exists tcp://172.30.10.59:44965
# distributed.core - ERROR - 'tcp://172.30.8.129:35045'
# Traceback (most recent call last):
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/core.py", line 471, in handle_stream
#     handler(**merge(extra, msg))
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 2326, in handle_release_data
#     ws = self.workers[worker]
# KeyError: 'tcp://172.30.8.129:35045'
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:38418 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:38392 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:38620 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:39040 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:39052 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:39080 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:39110 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:39314 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:39318 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:39328 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:39390 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:39454 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:39534 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:39546 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:39598 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:39610 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:39628 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:46824 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:46856 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:46966 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:46984 remote=tcp://172.30.100.3:34376>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:47098 remote=tcp://172.30.100.3:34376>
# distributed.core - ERROR - 'tcp://172.30.8.129:35635'
# Traceback (most recent call last):
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/core.py", line 412, in handle_comm
#     result = yield result
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 1500, in add_worker
#     yield self.handle_worker(comm=comm, worker=address)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 2416, in handle_worker
#     yield self.handle_stream(comm=comm, extra={"worker": worker})
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/core.py", line 471, in handle_stream
#     handler(**merge(extra, msg))
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 2326, in handle_release_data
#     ws = self.workers[worker]
# KeyError: 'tcp://172.30.8.129:35635'
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:47130 remote=tcp://172.30.100.3:34376>
# distributed.utils - ERROR - 'tcp://172.30.8.129:35635'
# Traceback (most recent call last):
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/utils.py", line 713, in log_errors
#     yield
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 1500, in add_worker
#     yield self.handle_worker(comm=comm, worker=address)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 2412, in handle_worker
#     worker_comm = self.stream_comms[worker]
# KeyError: 'tcp://172.30.8.129:35635'
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://172.30.100.3:48150 remote=tcp://172.30.100.3:34376>
# distributed.utils - ERROR - 'tcp://172.30.8.129:35045'
# Traceback (most recent call last):
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/utils.py", line 713, in log_errors
#     yield
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 1500, in add_worker
#     yield self.handle_worker(comm=comm, worker=address)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 2412, in handle_worker
#     worker_comm = self.stream_comms[worker]
# KeyError: 'tcp://172.30.8.129:35045'
# distributed.utils - ERROR - 'tcp://172.30.8.129:35771'
# Traceback (most recent call last):
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/utils.py", line 713, in log_errors
#     yield
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 1500, in add_worker
#     yield self.handle_worker(comm=comm, worker=address)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 2412, in handle_worker
#     worker_comm = self.stream_comms[worker]
# KeyError: 'tcp://172.30.8.129:35771'
# distributed.utils - ERROR - 'tcp://172.30.8.129:37711'
# Traceback (most recent call last):
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/utils.py", line 713, in log_errors
#     yield
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 1500, in add_worker
#     yield self.handle_worker(comm=comm, worker=address)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 2412, in handle_worker
#     worker_comm = self.stream_comms[worker]
# KeyError: 'tcp://172.30.8.129:37711'
# distributed.core - ERROR - 'tcp://172.30.8.129:35635'
# Traceback (most recent call last):
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/core.py", line 412, in handle_comm
#     result = yield result
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 1500, in add_worker
#     yield self.handle_worker(comm=comm, worker=address)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 2412, in handle_worker
#     worker_comm = self.stream_comms[worker]
# KeyError: 'tcp://172.30.8.129:35635'
# distributed.core - ERROR - 'tcp://172.30.8.129:35045'
# Traceback (most recent call last):
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/core.py", line 412, in handle_comm
#     result = yield result
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 1500, in add_worker
#     yield self.handle_worker(comm=comm, worker=address)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 2412, in handle_worker
#     worker_comm = self.stream_comms[worker]
# KeyError: 'tcp://172.30.8.129:35045'
# distributed.core - ERROR - 'tcp://172.30.8.129:35771'
# Traceback (most recent call last):
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/core.py", line 412, in handle_comm
#     result = yield result
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.throw(*exc_info)  # type: ignore
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 1500, in add_worker
#     yield self.handle_worker(comm=comm, worker=address)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 735, in run
#     value = future.result()
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/scratch/cnt0024/hmg2840/albert7a/anaconda3/lib/python3.7/site-packages/distributed/scheduler.py", line 2412, in handle_worker
#     worker_comm = self.stream_comms[worker]
# KeyError: 'tcp://172.30.8.129:35771'

# %%
10000*diff[0].mean(dim='time_counter').min().values
# Out:
# -0.0012305474683671491

# %%
10000*diff_br[0].mean(dim='time_counter').min().values

# %%
fig, ax = plt.subplots(1,1,figsize=(10,15))
diff=u2mean-u*u
diff[0].mean(dim='time_counter').where(mask[0]==1).plot(cmap='cmo.balance',ax=ax,vmin=-1,vmax=1,add_labels=True)

# %%
u2=u*u

# %%
v2=v*v

# %%
u2mean=u2.mean(dim='time_counter')

# %%
v2mean=v2.mean(dim='time_counter')

# %%
eke=compute_EKE(u,v,u2mean,v2mean)

# %%
eke
# Out:
# <xarray.DataArray (deptht: 300, y: 2862, x: 1218, time_counter: 31)>
# dask.array<shape=(300, 2862, 1218, 31), dtype=float32, chunksize=(1, 576, 342, 1)>
# Coordinates:
#   * deptht         (deptht) float32 0.48045477 1.5587916 ... 5974.8853 6025.346
#     time_centered  (time_counter) datetime64[ns] dask.array<shape=(31,), chunksize=(1,)>
#   * time_counter   (time_counter) datetime64[ns] 2013-01-01T12:00:00 ... 2013-01-31T12:00:00
# Dimensions without coordinates: y, x

# %%
plot_one_month(10000*eke[0],mask[0],0,2500,'cmo.amp','Surface EKE','eke_surf',month,year,m)
